# %%
import pandas as pd
import pickle

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
df = pd.DataFrame(columns=['Cement', 'Blast Furnace Slag', 
                           'Fly Ash', 'Water', 'Superplasticizer', 
                           'Coarse Aggregate', 'Fine Aggregate', 'Age'], 
                  data=[[540, 0, 0, 162, 2.5, 1055, 676, 28]])

# %%
model.predict(df)
# Out:
# array([66.1215])
